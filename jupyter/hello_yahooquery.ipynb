# %%
from yahooquery import Ticker

# %%
aapl = Ticker('aapl')

# %%
aapl.summary_detail
# Out:
# {'aapl': {'maxAge': 1,
#   'priceHint': 2,
#   'previousClose': 150.59,
#   'open': 150.21,
#   'dayLow': 147.61,
#   'dayHigh': 150.94,
#   'regularMarketPreviousClose': 150.59,
#   'regularMarketOpen': 150.21,
#   'regularMarketDayLow': 147.61,
#   'regularMarketDayHigh': 150.94,
#   'dividendRate': 0.92,
#   'dividendYield': 0.0061000003,
#   'exDividendDate': '2023-02-09 18:00:00',
#   'payoutRatio': 0.1545,
#   'fiveYearAvgDividendYield': 0.95,
#   'beta': 1.297088,
#   'trailingPE': 25.559381,
#   'forwardPE': 22.5,
#   'volume': 68572400,
#   'regularMarketVolume': 68572400,
#   'averageVolume': 72469903,
#   'averageVolume10days': 58723390,
#   'averageDailyVolume10Day': 58723390,
#   'bid': 148.58,
#   'ask': 148.6,
#   'bidSize': 1300,
#   'askSize': 800,
#   'marketCap': 2349552107520,
#   'fiftyTwoWeekLow': 124.17,
#   'fiftyTwoWeekHigh': 179.61,
#   'priceToSalesTrailing12Months': 6.0627813,
#   'fiftyDayAverage': 143.384,
#   'twoHundredDayAverage': 147.4538,
#   'trailingAnnualDividendRate': 0.91,
#   'trailingAnnualDividendYield': 0.006042898,
#   'currency': 'USD',
#   'fromCurrency': None,
#   'toCurrency': None,
#   'lastMarket': None,
#   'coinMarketCapLink': None,
#   'algorithm': None,
#   'tradeable': False}}

# %%
symbols = ['meta', 'aapl', 'amzn', 'nflx', 'goog']

# %%
faang = Ticker(symbols)

# %%
faang.summary_detail
# Out:
# {'meta': {'maxAge': 1,
#   'priceHint': 2,
#   'previousClose': 181.69,
#   'open': 181.01,
#   'dayLow': 178.8,
#   'dayHigh': 184.77,
#   'regularMarketPreviousClose': 181.69,
#   'regularMarketOpen': 181.01,
#   'regularMarketDayLow': 178.8,
#   'regularMarketDayHigh': 184.77,
#   'payoutRatio': 0.0,
#   'beta': 1.179936,
#   'trailingPE': 21.446833,
#   'forwardPE': 15.63676,
#   'volume': 25665032,
#   'regularMarketVolume': 25665032,
#   'averageVolume': 32175910,
#   'averageVolume10days': 30097360,
#   'averageDailyVolume10Day': 30097360,
#   'bid': 182.11,
#   'ask': 182.3,
#   'bidSize': 800,
#   'askSize': 1800,
#   'marketCap': 465404788736,
#   'fiftyTwoWeekLow': 88.09,
#   'fiftyTwoWeekHigh': 236.86,
#   'priceToSalesTrailing12Months': 3.9911566,
#   'fiftyDayAverage': 158.0618,
#   'twoHundredDayAverage': 149.53406,
#   'trailingAnnualDividendRate': 0.0,
#   'trailingAnnualDividendYield': 0.0,
#   'currency': 'USD',
#   'fromCurrency': None,
#   'toCurrency': None,
#   'lastMarket': None,
#   'coinMarketCapLink': None,
#   'algorithm': None,
#   'tradeable': False},
#  'aapl': {'maxAge': 1,
#   'priceHint': 2,
#   'previousClose': 150.59,
#   'open': 150.21,
#   'dayLow': 147.61,
#   'dayHigh': 150.94,
#   'regularMarketPreviousClose': 150.59,
#   'regularMarketOpen': 150.21,
#   'regularMarketDayLow': 147.61,
#   'regularMarketDayHigh': 150.94,
#   'dividendRate': 0.92,
#   'dividendYield': 0.0061000003,
#   'exDividendDate': '2023-02-09 18:00:00',
#   'payoutRatio': 0.1545,
#   'fiveYearAvgDividendYield': 0.95,
#   'beta': 1.297088,
#   'trailingPE': 25.559381,
#   'forwardPE': 22.5,
#   'volume': 68572400,
#   'regularMarketVolume': 68572400,
#   'averageVolume': 72469903,
#   'averageVolume10days': 58723390,
#   'averageDailyVolume10Day': 58723390,
#   'bid': 148.58,
#   'ask': 148.6,
#   'bidSize': 1300,
#   'askSize': 800,
#   'marketCap': 2349552107520,
#   'fiftyTwoWeekLow': 124.17,
#   'fiftyTwoWeekHigh': 179.61,
#   'priceToSalesTrailing12Months': 6.0627813,
#   'fiftyDayAverage': 143.384,
#   'twoHundredDayAverage': 147.4538,
#   'trailingAnnualDividendRate': 0.91,
#   'trailingAnnualDividendYield': 0.006042898,
#   'currency': 'USD',
#   'fromCurrency': None,
#   'toCurrency': None,
#   'lastMarket': None,
#   'coinMarketCapLink': None,
#   'algorithm': None,
#   'tradeable': False},
#  'amzn': {'maxAge': 1,
#   'priceHint': 2,
#   'previousClose': 92.25,
#   'open': 92.67,
#   'dayLow': 90.245,
#   'dayHigh': 93.57,
#   'regularMarketPreviousClose': 92.25,
#   'regularMarketOpen': 92.67,
#   'regularMarketDayLow': 90.245,
#   'regularMarketDayHigh': 93.57,
#   'payoutRatio': 0.0,
#   'beta': 1.253595,
#   'forwardPE': 36.14741,
#   'volume': 69827490,
#   'regularMarketVolume': 69827490,
#   'averageVolume': 71417794,
#   'averageVolume10days': 52701220,
#   'averageDailyVolume10Day': 52701220,
#   'bid': 90.95,
#   'ask': 90.98,
#   'bidSize': 3100,
#   'askSize': 1200,
#   'marketCap': 929737539584,
#   'fiftyTwoWeekLow': 81.43,
#   'fiftyTwoWeekHigh': 170.8315,
#   'priceToSalesTrailing12Months': 1.8088877,
#   'fiftyDayAverage': 95.2588,
#   'twoHundredDayAverage': 108.764915,
#   'trailingAnnualDividendRate': 0.0,
#   'trailingAnnualDividendYield': 0.0,
#   'currency': 'USD',
#   'fromCurrency': None,
#   'toCurrency': None,
#   'lastMarket': None,
#   'coinMarketCapLink': None,
#   'algorithm': None,
#   'tradeable': False},
#  'nflx': {'maxAge': 1,
#   'priceHint': 2,
#   'previousClose': 297.78,
#   'open': 297.905,
#   'dayLow': 289.0,
#   'dayHigh': 298.79,
#   'regularMarketPreviousClose': 297.78,
#   'regularMarketOpen': 297.905,
#   'regularMarketDayLow': 289.0,
#   'regularMarketDayHigh': 298.79,
#   'payoutRatio': 0.0,
#   'beta': 1.258856,
#   'trailingPE': 30.947147,
#   'forwardPE': 20.288288,
#   'volume': 5759315,
#   'regularMarketVolume': 5759315,
#   'averageVolume': 8004476,
#   'averageVolume10days': 5248020,
#   'averageDailyVolume10Day': 5248020,
#   'bid': 292.1,
#   'ask': 292.42,
#   'bidSize': 3200,
#   'askSize': 800,
#   'marketCap': 130379792384,
#   'fiftyTwoWeekLow': 162.71,
#   'fiftyTwoWeekHigh': 396.5,
#   'priceToSalesTrailing12Months': 4.123914,
#   'fiftyDayAverage': 333.0858,
#   'twoHundredDayAverage': 262.56155,
#   'trailingAnnualDividendRate': 0.0,
#   'trailingAnnualDividendYield': 0.0,
#   'currency': 'USD',
#   'fromCurrency': None,
#   'toCurrency': None,
#   'lastMarket': None,
#   'coinMarketCapLink': None,
#   'algorithm': None,
#   'tradeable': False},
#  'goog': {'maxAge': 1,
#   'priceHint': 2,
#   'previousClose': 92.66,
#   'open': 92.5,
#   'dayLow': 90.8,
#   'dayHigh': 93.18,
#   'regularMarketPreviousClose': 92.66,
#   'regularMarketOpen': 92.5,
#   'regularMarketDayLow': 90.8,
#   'regularMarketDayHigh': 93.18,
#   'payoutRatio': 0.0,
#   'beta': 1.090845,
#   'trailingPE': 20.684092,
#   'forwardPE': 14.944171,
#   'volume': 32850092,
#   'regularMarketVolume': 32850092,
#   'averageVolume': 30107983,
#   'averageVolume10days': 26820010,
#   'averageDailyVolume10Day': 26820010,
#   'bid': 91.07,
#   'ask': 91.15,
#   'bidSize': 1200,
#   'askSize': 1000,
#   'marketCap': 1162962141184,
#   'fiftyTwoWeekLow': 83.45,
#   'fiftyTwoWeekHigh': 144.1625,
#   'priceToSalesTrailing12Months': 4.1117897,
#   'fiftyDayAverage': 94.5748,
#   'twoHundredDayAverage': 102.698944,
#   'trailingAnnualDividendRate': 0.0,
#   'trailingAnnualDividendYield': 0.0,
#   'currency': 'USD',
#   'fromCurrency': None,
#   'toCurrency': None,
#   'lastMarket': None,
#   'coinMarketCapLink': None,
#   'algorithm': None,
#   'tradeable': False}}
