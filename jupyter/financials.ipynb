# %%
from yahooquery import Ticker

# %%
coin = Ticker('coin')

# %%
cash_flow = coin.cash_flow()

# %%
cash_flow.CapitalExpenditure
# Out:
# symbol
# coin   -40471000.0
# coin   -18802000.0
# coin   -85783000.0
# coin   -63971000.0
# coin   -63971000.0
# Name: CapitalExpenditure, dtype: float64

# %%
cash_flow.FreeCashFlow
# Out:
# symbol
# coin   -1.210650e+08
# coin    2.985268e+09
# coin    1.064425e+10
# coin   -1.649390e+09
# coin   -1.649390e+09
# Name: FreeCashFlow, dtype: float64

# %%
coin.balance_sheet()
# Out:
#          asOfDate periodType currencyCode  AccountsPayable  \
# symbol
# coin   2019-12-31        12M          USD        5940000.0
# coin   2020-12-31        12M          USD       12031000.0
# coin   2021-12-31        12M          USD       39833000.0
# coin   2022-12-31        12M          USD       56043000.0
#
#         AccountsReceivable  AccruedInterestReceivable  \
# symbol
# coin            17604000.0                  2175000.0
# coin           163133000.0                 21709000.0
# coin           128312000.0                 73803000.0
# coin             8434000.0                223413000.0
#
#         AccumulatedDepreciation  AdditionalPaidInCapital  \
# symbol
# coin                -10408000.0             9.382000e+07
# coin                -24488000.0             7.934900e+08
# coin                -42246000.0             2.034658e+09
# coin                -85015000.0             3.767686e+09
#
#         AvailableForSaleSecurities  CapitalLeaseObligations  ...  \
# ...

# %%
coin.balance_sheet(frequency='Quarterly')
# Out:
#          asOfDate periodType currencyCode  AccountsPayable  \
# symbol
# coin   2021-12-31         3M          USD       39833000.0
# coin   2022-03-31         3M          USD       12650000.0
# coin   2022-06-30         3M          USD       40745000.0
# coin   2022-09-30         3M          USD       61514000.0
# coin   2022-12-31         3M          USD       56043000.0
#
#         AccountsReceivable  AccruedInterestReceivable  \
# symbol
# coin           128312000.0                 73803000.0
# coin            87544000.0                 60599000.0
# coin            73623000.0                 61524000.0
# coin            61541000.0                 79164000.0
# coin             8434000.0                223413000.0
#
#         AccumulatedDepreciation  AdditionalPaidInCapital  \
# symbol
# coin                -42246000.0             2.034658e+09
# coin                        NaN             2.579216e+09
# coin                        NaN             3.004459e+09
# ...
